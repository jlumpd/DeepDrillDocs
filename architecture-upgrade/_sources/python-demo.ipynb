# %% [markdown]
# # Pyhton教学文档

# %%
print(add(3,4))
# Out:
# 7
# None

# %%
print("a+b=", 3+4)
# Out:
# a+b= 7

# %%
def add(a,b):
    print(a+b)

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/12.6 MB 2.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.8/12.6 MB 2.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.6 MB 4.4 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.6 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 7.3 MB/s eta 0:00:00
# ...

# %%
import numpy

# %% [markdown]
# 以上，要注意Python语法。
#
# |a|a|
# |-|-|
# |333|32|
